# %%
import cv2
video_file_path = "./data/video/section_cam.mp4"

vid = cv2.VideoCapture(video_file_path)

return_value, frame = vid.read()

# while vid.isOpened():
#     return_value, frame = vid.read()
#     if return_value:
#         cv2.imshow("output", frame)
#     else:
#         break
# cv2.destroyAllWindows()

# %%
cv2.imwrite("frame.jpg", frame)
# Out:
# True

# %%
mask = cv2.imread("masking.jpg")//255
# rgb_mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

plt.imshow(rgb_frame)

# %%
plt.imshow(mask * rgb_frame)

# %%
length = vid.get(cv2.CAP_PROP_FRAME_COUNT)
width = vid.get(cv2.CAP_PROP_FRAME_WIDTH)
height = vid.get(cv2.CAP_PROP_FRAME_HEIGHT)

length, width, height
# Out:
# (18002.0, 1920.0, 1080.0)
